# %% [markdown]
# Loading Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk

# %% [markdown]
# Reading CSV file

# %%
df = pd.read_csv('Email-spam.csv')
df
# Out:
#      ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                    ham\tOk lar... Joking wif u oni...
# 1     spam\tFree entry in 2 a wkly comp to win FA Cu...
# 2     ham\tU dun say so early hor... U c already the...
# 3     ham\tNah I don't think he goes to usf, he live...
# 4     spam\tFreeMsg Hey there darling it's been 3 we...
# 5     ham\tEven my brother is not like to speak with...
# 6     ham\tAs per your request 'Melle Melle (Oru Min...
# 7     spam\tWINNER!! As a valued network customer yo...
# 8     spam\tHad your mobile 11 months or more? U R e...
# 9     ham\tI'm gonna be home soon and i don't want t...
# 10    spam\tSIX chances to win CASH! From 100 to 20,...
# 11    spam\tURGENT! You have won a 1 week FREE membe...
# 12    ham\tI've been searching for the right words t...
# 13             ham\tI HAVE A DATE ON SUNDAY WITH WILL!!
# 14    spam\tXXXMobileMovieClub: To use your credit, ...
# 15                      ham\tOh k...i'm watching here:)
# 16    ham\tEh u remember how 2 spell his name... Yes...
# 17    ham\tFine if thats the way u feel. Thats the...
# 18    spam\tEngland v Macedonia - dont miss the goal...
# 19       ham\tIs that seriously how you spell his name?
# 20    ham\tI‘m going to try for 2 months ha ha only ...
# 21    ham\tSo ü pay first lar... Then when is da sto...
# 22    ham\tAft i finish my lunch then i go str down ...
# 23    ham\tFfffffffff. Alright no way I can meet up ...
# 24    ham\tJust forced myself to eat a slice. I'm re...
# 25                  ham\tLol your always so convincing.
# 26    ham\tDid you catch the bus ? Are you frying an...
# 27    ham\tI'm back &amp; we're packing the car now,...
# 28    ham\tAhhh. Work. I vaguely remember that! What...
# 29    ham\tWait that's still not all that clear, wer...
# ...                                                 ...
# 5543      ham\tArmand says get your ass over to epsilon
# 5544        ham\tU still havent got urself a jacket ah?
# 5545  ham\tI'm taking derek &amp; taylor to walmart,...
# 5546  ham\tHi its in durban are you still on this nu...
# 5547    ham\tIc. There are a lotta childporn cars then.
# 5548  spam\tHad your contract mobile 11 Mnths? Lates...
# 5549            ham\tNo, I was trying it all weekend ;V
# 5550  ham\tYou know, wot people wear. T shirts, jump...
# 5551   ham\tCool, what time you think you can get here?
# 5552  ham\tWen did you get so spiritual and deep. Th...
# 5553  ham\tHave a safe trip to Nigeria. Wish you hap...
# 5554                   ham\tHahaha..use your brain dear
# 5555  ham\tWell keep in mind I've only got enough ga...
# 5556  ham\tYeh. Indians was nice. Tho it did kane me...
# 5557  ham\tYes i have. So that's why u texted. Pshew...
# 5558  ham\tNo. I meant the calculation is the same. ...
# 5559                        ham\tSorry, I'll call later
# 5560  ham\tif you aren't here in the next  &lt;#&gt;...
# 5561             ham\tAnything lor. Juz both of us lor.
# 5562  ham\tGet me out of this dump heap. My mom deci...
# 5563  ham\tOk lor... Sony ericsson salesman... I ask...
# 5564                           ham\tArd 6 like dat lor.
# 5565  ham\tWhy don't you wait 'til at least wednesda...
# 5566                                  ham\tHuh y lei...
# 5567  spam\tREMINDER FROM O2: To get 2.50 pounds fre...
# 5568  spam\tThis is the 2nd time we have tried 2 con...
# 5569          ham\tWill ü b going to esplanade fr home?
# 5570  ham\tPity, * was in mood for that. So...any ot...
# 5571  ham\tThe guy did some bitching but I acted lik...
# 5572                    ham\tRofl. Its true to its name
#
# [5573 rows x 1 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#      ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                    ham\tOk lar... Joking wif u oni...
# 1     spam\tFree entry in 2 a wkly comp to win FA Cu...
# 2     ham\tU dun say so early hor... U c already the...
# 3     ham\tNah I don't think he goes to usf, he live...
# 4     spam\tFreeMsg Hey there darling it's been 3 we...
# 5     ham\tEven my brother is not like to speak with...
# 6     ham\tAs per your request 'Melle Melle (Oru Min...
# 7     spam\tWINNER!! As a valued network customer yo...
# 8     spam\tHad your mobile 11 months or more? U R e...
# 9     ham\tI'm gonna be home soon and i don't want t...
# 10    spam\tSIX chances to win CASH! From 100 to 20,...
# 11    spam\tURGENT! You have won a 1 week FREE membe...
# 12    ham\tI've been searching for the right words t...
# 13             ham\tI HAVE A DATE ON SUNDAY WITH WILL!!
# 14    spam\tXXXMobileMovieClub: To use your credit, ...
# 15                      ham\tOh k...i'm watching here:)
# 16    ham\tEh u remember how 2 spell his name... Yes...
# 17    ham\tFine if thats the way u feel. Thats the...
# 18    spam\tEngland v Macedonia - dont miss the goal...
# 19       ham\tIs that seriously how you spell his name?
# 20    ham\tI‘m going to try for 2 months ha ha only ...
# 21    ham\tSo ü pay first lar... Then when is da sto...
# 22    ham\tAft i finish my lunch then i go str down ...
# 23    ham\tFfffffffff. Alright no way I can meet up ...
# 24    ham\tJust forced myself to eat a slice. I'm re...
# 25                  ham\tLol your always so convincing.
# 26    ham\tDid you catch the bus ? Are you frying an...
# 27    ham\tI'm back &amp; we're packing the car now,...
# 28    ham\tAhhh. Work. I vaguely remember that! What...
# 29    ham\tWait that's still not all that clear, wer...
# ...                                                 ...
# 5543      ham\tArmand says get your ass over to epsilon
# 5544        ham\tU still havent got urself a jacket ah?
# 5545  ham\tI'm taking derek &amp; taylor to walmart,...
# 5546  ham\tHi its in durban are you still on this nu...
# 5547    ham\tIc. There are a lotta childporn cars then.
# 5548  spam\tHad your contract mobile 11 Mnths? Lates...
# 5549            ham\tNo, I was trying it all weekend ;V
# 5550  ham\tYou know, wot people wear. T shirts, jump...
# 5551   ham\tCool, what time you think you can get here?
# 5552  ham\tWen did you get so spiritual and deep. Th...
# 5553  ham\tHave a safe trip to Nigeria. Wish you hap...
# 5554                   ham\tHahaha..use your brain dear
# 5555  ham\tWell keep in mind I've only got enough ga...
# 5556  ham\tYeh. Indians was nice. Tho it did kane me...
# 5557  ham\tYes i have. So that's why u texted. Pshew...
# 5558  ham\tNo. I meant the calculation is the same. ...
# 5559                        ham\tSorry, I'll call later
# 5560  ham\tif you aren't here in the next  &lt;#&gt;...
# 5561             ham\tAnything lor. Juz both of us lor.
# 5562  ham\tGet me out of this dump heap. My mom deci...
# 5563  ham\tOk lor... Sony ericsson salesman... I ask...
# 5564                           ham\tArd 6 like dat lor.
# 5565  ham\tWhy don't you wait 'til at least wednesda...
# 5566                                  ham\tHuh y lei...
# 5567  spam\tREMINDER FROM O2: To get 2.50 pounds fre...
# 5568  spam\tThis is the 2nd time we have tried 2 con...
# 5569          ham\tWill ü b going to esplanade fr home?
# 5570  ham\tPity, * was in mood for that. So...any ot...
# 5571  ham\tThe guy did some bitching but I acted lik...
# 5572                    ham\tRofl. Its true to its name
#
# [5573 rows x 1 columns]

# %%
col = df.columns

# %%
col
# Out:
# Index(['ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'], dtype='object')

# %%
temp_df = df

# %%
temp_df.iloc[0:1,0:2]
# Out:
#   ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                 ham\tOk lar... Joking wif u oni...

# %%
temp_df.columns = ['filter']

# %%
line = temp_df[:1]

# %%
line
# Out:
#                                filter
# 0  ham\tOk lar... Joking wif u oni...

# %%
temp_df.append(line)
# Out:
#                                                  filter
# 0                    ham\tOk lar... Joking wif u oni...
# 1     spam\tFree entry in 2 a wkly comp to win FA Cu...
# 2     ham\tU dun say so early hor... U c already the...
# 3     ham\tNah I don't think he goes to usf, he live...
# 4     spam\tFreeMsg Hey there darling it's been 3 we...
# 5     ham\tEven my brother is not like to speak with...
# 6     ham\tAs per your request 'Melle Melle (Oru Min...
# 7     spam\tWINNER!! As a valued network customer yo...
# 8     spam\tHad your mobile 11 months or more? U R e...
# 9     ham\tI'm gonna be home soon and i don't want t...
# 10    spam\tSIX chances to win CASH! From 100 to 20,...
# 11    spam\tURGENT! You have won a 1 week FREE membe...
# 12    ham\tI've been searching for the right words t...
# 13             ham\tI HAVE A DATE ON SUNDAY WITH WILL!!
# 14    spam\tXXXMobileMovieClub: To use your credit, ...
# 15                      ham\tOh k...i'm watching here:)
# 16    ham\tEh u remember how 2 spell his name... Yes...
# 17    ham\tFine if thats the way u feel. Thats the...
# 18    spam\tEngland v Macedonia - dont miss the goal...
# 19       ham\tIs that seriously how you spell his name?
# 20    ham\tI‘m going to try for 2 months ha ha only ...
# 21    ham\tSo ü pay first lar... Then when is da sto...
# 22    ham\tAft i finish my lunch then i go str down ...
# 23    ham\tFfffffffff. Alright no way I can meet up ...
# 24    ham\tJust forced myself to eat a slice. I'm re...
# 25                  ham\tLol your always so convincing.
# 26    ham\tDid you catch the bus ? Are you frying an...
# 27    ham\tI'm back &amp; we're packing the car now,...
# 28    ham\tAhhh. Work. I vaguely remember that! What...
# 29    ham\tWait that's still not all that clear, wer...
# ...                                                 ...
# 5544        ham\tU still havent got urself a jacket ah?
# 5545  ham\tI'm taking derek &amp; taylor to walmart,...
# 5546  ham\tHi its in durban are you still on this nu...
# 5547    ham\tIc. There are a lotta childporn cars then.
# 5548  spam\tHad your contract mobile 11 Mnths? Lates...
# 5549            ham\tNo, I was trying it all weekend ;V
# 5550  ham\tYou know, wot people wear. T shirts, jump...
# 5551   ham\tCool, what time you think you can get here?
# 5552  ham\tWen did you get so spiritual and deep. Th...
# 5553  ham\tHave a safe trip to Nigeria. Wish you hap...
# 5554                   ham\tHahaha..use your brain dear
# 5555  ham\tWell keep in mind I've only got enough ga...
# 5556  ham\tYeh. Indians was nice. Tho it did kane me...
# 5557  ham\tYes i have. So that's why u texted. Pshew...
# 5558  ham\tNo. I meant the calculation is the same. ...
# 5559                        ham\tSorry, I'll call later
# 5560  ham\tif you aren't here in the next  &lt;#&gt;...
# 5561             ham\tAnything lor. Juz both of us lor.
# 5562  ham\tGet me out of this dump heap. My mom deci...
# 5563  ham\tOk lor... Sony ericsson salesman... I ask...
# 5564                           ham\tArd 6 like dat lor.
# 5565  ham\tWhy don't you wait 'til at least wednesda...
# 5566                                  ham\tHuh y lei...
# 5567  spam\tREMINDER FROM O2: To get 2.50 pounds fre...
# 5568  spam\tThis is the 2nd time we have tried 2 con...
# 5569          ham\tWill ü b going to esplanade fr home?
# 5570  ham\tPity, * was in mood for that. So...any ot...
# 5571  ham\tThe guy did some bitching but I acted lik...
# 5572                    ham\tRofl. Its true to its name
# 0                    ham\tOk lar... Joking wif u oni...
#
# [5574 rows x 1 columns]

# %%
temp_df.reset_index(inplace=True,drop=True)

# %%
temp_df.head()
# Out:
#                                               filter
# 0                 ham\tOk lar... Joking wif u oni...
# 1  spam\tFree entry in 2 a wkly comp to win FA Cu...
# 2  ham\tU dun say so early hor... U c already the...
# 3  ham\tNah I don't think he goes to usf, he live...
# 4  spam\tFreeMsg Hey there darling it's been 3 we...

# %%
temp_df.columns = ['text']

# %%
temp_df.shape
# Out:
# (5573, 1)

# %%
filter = []

# %%
def text_to_filter(text):
    if text.startswith('ham'):
        filter.append('ham')
    elif text.startswith('spam'):
        filter.append('spam')

# %%
temp_df['text'].apply(text_to_filter)
filter
# Out:
# ['ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  ...]

# %%
filter = pd.DataFrame(filter)

# %%
filter.shape
# Out:
# (5573, 1)

# %%
temp_df.shape
# Out:
# (5573, 1)

# %%
temp_df['filter'] = filter

# %%
temp_df.head()
# Out:
#                                                 text filter
# 0                 ham\tOk lar... Joking wif u oni...    ham
# 1  spam\tFree entry in 2 a wkly comp to win FA Cu...   spam
# 2  ham\tU dun say so early hor... U c already the...    ham
# 3  ham\tNah I don't think he goes to usf, he live...    ham
# 4  spam\tFreeMsg Hey there darling it's been 3 we...   spam

# %% [markdown]
# WordCloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
words = ' '.join(temp_df['clean_text'])

# %%
wordcloud = WordCloud(stopwords =  STOPWORDS, background_color='black',height = 2500, width = 3000).generate(words)

# %%
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# Cleaning Data

# %%
from nltk.corpus import stopwords
from nltk.stem import  PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
#import nltk
#nltk.download()

# %%
lemmatizer = WordNetLemmatizer()
stopw = set(stopwords.words("english"))
stopw.update(".", "?", "(", ")", ",", "-", "'", '"',"/","2","1","3","4","5","6","7","8","9","10","&")

# %%
def text_to_words(raw_text):
    
    pos_t = (pos_tag(word_tokenize(raw_text)))
    words = raw_text.lower()
    
    lemmatizer.lemmatize(words)
    words = words.split()
    words = [word for word in words if not word.startswith('ham')]
    words = [word for word in words if not word.startswith('spam')]
    
    meaningful_words = [w for w in words if not w in stopw]
    
    return (" ".join(meaningful_words))

# %%
temp_df['clean_text'] = temp_df['text'].apply(text_to_words)
temp_df
# Out:
#                                                    text filter  \
# 0                    ham\tOk lar... Joking wif u oni...    ham
# 1     spam\tFree entry in 2 a wkly comp to win FA Cu...   spam
# 2     ham\tU dun say so early hor... U c already the...    ham
# 3     ham\tNah I don't think he goes to usf, he live...    ham
# 4     spam\tFreeMsg Hey there darling it's been 3 we...   spam
# 5     ham\tEven my brother is not like to speak with...    ham
# 6     ham\tAs per your request 'Melle Melle (Oru Min...    ham
# 7     spam\tWINNER!! As a valued network customer yo...   spam
# 8     spam\tHad your mobile 11 months or more? U R e...   spam
# 9     ham\tI'm gonna be home soon and i don't want t...    ham
# 10    spam\tSIX chances to win CASH! From 100 to 20,...   spam
# 11    spam\tURGENT! You have won a 1 week FREE membe...   spam
# 12    ham\tI've been searching for the right words t...    ham
# 13             ham\tI HAVE A DATE ON SUNDAY WITH WILL!!    ham
# 14    spam\tXXXMobileMovieClub: To use your credit, ...   spam
# 15                      ham\tOh k...i'm watching here:)    ham
# 16    ham\tEh u remember how 2 spell his name... Yes...    ham
# 17    ham\tFine if thats the way u feel. Thats the...    ham
# 18    spam\tEngland v Macedonia - dont miss the goal...   spam
# 19       ham\tIs that seriously how you spell his name?    ham
# 20    ham\tI‘m going to try for 2 months ha ha only ...    ham
# 21    ham\tSo ü pay first lar... Then when is da sto...    ham
# 22    ham\tAft i finish my lunch then i go str down ...    ham
# 23    ham\tFfffffffff. Alright no way I can meet up ...    ham
# 24    ham\tJust forced myself to eat a slice. I'm re...    ham
# 25                  ham\tLol your always so convincing.    ham
# 26    ham\tDid you catch the bus ? Are you frying an...    ham
# 27    ham\tI'm back &amp; we're packing the car now,...    ham
# 28    ham\tAhhh. Work. I vaguely remember that! What...    ham
# 29    ham\tWait that's still not all that clear, wer...    ham
# ...                                                 ...    ...
# 5543      ham\tArmand says get your ass over to epsilon    ham
# 5544        ham\tU still havent got urself a jacket ah?    ham
# 5545  ham\tI'm taking derek &amp; taylor to walmart,...    ham
# 5546  ham\tHi its in durban are you still on this nu...    ham
# 5547    ham\tIc. There are a lotta childporn cars then.    ham
# 5548  spam\tHad your contract mobile 11 Mnths? Lates...   spam
# 5549            ham\tNo, I was trying it all weekend ;V    ham
# 5550  ham\tYou know, wot people wear. T shirts, jump...    ham
# 5551   ham\tCool, what time you think you can get here?    ham
# 5552  ham\tWen did you get so spiritual and deep. Th...    ham
# 5553  ham\tHave a safe trip to Nigeria. Wish you hap...    ham
# 5554                   ham\tHahaha..use your brain dear    ham
# 5555  ham\tWell keep in mind I've only got enough ga...    ham
# 5556  ham\tYeh. Indians was nice. Tho it did kane me...    ham
# 5557  ham\tYes i have. So that's why u texted. Pshew...    ham
# 5558  ham\tNo. I meant the calculation is the same. ...    ham
# 5559                        ham\tSorry, I'll call later    ham
# 5560  ham\tif you aren't here in the next  &lt;#&gt;...    ham
# 5561             ham\tAnything lor. Juz both of us lor.    ham
# 5562  ham\tGet me out of this dump heap. My mom deci...    ham
# 5563  ham\tOk lor... Sony ericsson salesman... I ask...    ham
# 5564                           ham\tArd 6 like dat lor.    ham
# 5565  ham\tWhy don't you wait 'til at least wednesda...    ham
# 5566                                  ham\tHuh y lei...    ham
# 5567  spam\tREMINDER FROM O2: To get 2.50 pounds fre...   spam
# 5568  spam\tThis is the 2nd time we have tried 2 con...   spam
# 5569          ham\tWill ü b going to esplanade fr home?    ham
# 5570  ham\tPity, * was in mood for that. So...any ot...    ham
# 5571  ham\tThe guy did some bitching but I acted lik...    ham
# 5572                    ham\tRofl. Its true to its name    ham
#
#                                              clean_text
# 0                         ok lar... joking wif u oni...
# 1     free entry wkly comp win fa cup final tkts 21s...
# 2             u dun say early hor... u c already say...
# 3               nah think goes usf, lives around though
# 4     freemsg hey darling week's word back! i'd like...
# 5     even brother like speak me. treat like aids pa...
# 6     per request 'melle melle (oru minnaminunginte ...
# 7     winner!! valued network customer selected rece...
# 8     mobile 11 months more? u r entitled update lat...
# 9     i'm gonna home soon want talk stuff anymore to...
# 10    six chances win cash! 100 20,000 pounds txt> c...
# 11    urgent! week free membership £100,000 prize ja...
# 12    i've searching right words thank breather. pro...
# 13                                   date sunday will!!
# 14    xxxmobilemovieclub: use credit, click wap link...
# 15                           oh k...i'm watching here:)
# 16    eh u remember spell name... yes did. v naughty...
# 17            fine thats way u feel. thats way gota b
# 18    england v macedonia dont miss goals/team news....
# 19                                seriously spell name?
# 20                    i‘m going try months ha ha joking
# 21                 ü pay first lar... da stock comin...
# 22    aft finish lunch go str lor. ard smth lor. u f...
# 23                 ffffffffff. alright way meet sooner?
# 24    forced eat slice. i'm really hungry tho. sucks...
# 25                               lol always convincing.
# 26    catch bus frying egg make tea? eating mom's le...
# 27    i'm back &amp; we're packing car now, i'll let...
# 28    ahhh. work. vaguely remember that! feel like? lol
# 29    wait that's still clear, sure sarcastic that's...
# ...                                                 ...
# 5543                        armand says get ass epsilon
# 5544               u still havent got urself jacket ah?
# 5545  i'm taking derek &amp; taylor walmart, i'm bac...
# 5546                             hi durban still number
# 5547                     ic. lotta childporn cars then.
# 5548  contract mobile 11 mnths? latest motorola, nok...
# 5549                              no, trying weekend ;v
# 5550  know, wot people wear. shirts, jumpers, hat, b...
# 5551                         cool, time think get here?
# 5552               wen get spiritual deep. that's great
# 5553  safe trip nigeria. wish happiness soon company...
# 5554                             hahaha..use brain dear
# 5555  well keep mind i've got enough gas one round t...
# 5556  yeh. indians nice. tho kane bit he. shud go dr...
# 5557    yes have. that's u texted. pshew...missing much
# 5558  no. meant calculation same. &lt;#&gt; units &l...
# 5559                             sorry, i'll call later
# 5560                next &lt;#&gt; hours imma flip shit
# 5561                          anything lor. juz us lor.
# 5562     get dump heap. mom decided come lowes. boring.
# 5563  ok lor... sony ericsson salesman... ask shuhui...
# 5564                                  ard like dat lor.
# 5565                  wait 'til least wednesday see get
# 5566                                         huh lei...
# 5567  reminder o2: get 2.50 pounds free call credit ...
# 5568  2nd time tried contact u. u £750 pound prize. ...
# 5569                       ü b going esplanade fr home?
# 5570           pity, * mood that. so...any suggestions?
# 5571  guy bitching acted like i'd interested buying ...
# 5572                                    rofl. true name
#
# [5573 rows x 3 columns]

# %%
target= temp_df['filter']

# %%
data = temp_df['text']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
clf.score(y_train, y_test)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB()
clf.fit(x_train, y_train)
clf.score(y_train, y_test)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
clf.score(y_train, y_test)

# %%
clf = GaussianNB()
clf.fit(x_train, y_train)
clf.score(y_train, y_test)

# %%
from sklearn.svm import SVC

# %%
clf_s = SVC(kernel = 'rbf',C=600,gamma= 0.01 )
clf.fit(x_train, y_train)
clf.score(y_train, y_test)

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf_n = MLPClassifier(hidden_layer_sizes = (4,3))
clf.fit(x_train, y_train)
clf.score(y_train, y_test)

# %%
clf_n = MLPClassifier(hidden_layer_sizes = (18,10) ,solver='sgd')
clf.fit(x_train, y_train)
clf.score(y_train, y_test)
