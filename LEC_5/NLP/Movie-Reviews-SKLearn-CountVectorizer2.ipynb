# %%
from nltk.corpus import movie_reviews

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids('neg')
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %%
movie_reviews.words(movie_reviews.fileids()[5])
# Out:
# ['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...]

# %%
documents = []
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))
documents[0:5]
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'a', 'mentally', 'unstable', 'man', ...], 'neg')]

# %%
import random
random.shuffle(documents)
documents[0:5]
# Out:
# [(['"', 'footloose', '"', 'has', 'only', 'one', 'goal', ...], 'pos'),
#  (['i', 'suppose', 'an', 'argument', 'could', 'be', ...], 'pos'),
#  (['the', 'andromeda', 'strain', 'is', 'the', 'greatest', ...], 'pos'),
#  (['urban', 'legend', 'surprised', 'me', '.', 'based', ...], 'pos'),
#  (['the', 'most', 'interesting', 'part', 'of', '"', ...], 'neg')]

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):
    
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk import pos_tag
w = "better"
pos_tag([w])
# Out:
# [('better', 'RBR')]

# %%
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)
stops, string.punctuation
# Out:
# ({'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   'a',
#   'about',
#   'above',
#   'after',
#   'again',
#   'against',
#   'ain',
#   'all',
#   'am',
#   'an',
#   'and',
#   'any',
#   'are',
#   'aren',
#   "aren't",
#   'as',
#   'at',
#   'be',
#   'because',
#   'been',
#   'before',
#   'being',
#   'below',
#   'between',
#   'both',
#   'but',
#   'by',
#   'can',
#   'couldn',
#   "couldn't",
#   'd',
#   'did',
#   'didn',
#   "didn't",
#   'do',
#   'does',
#   'doesn',
#   "doesn't",
#   'doing',
#   'don',
#   "don't",
#   'down',
#   'during',
#   'each',
#   'few',
#   'for',
#   'from',
#   'further',
#   'had',
#   'hadn',
#   "hadn't",
#   'has',
#   'hasn',
#   "hasn't",
#   'have',
#   'haven',
#   "haven't",
#   'having',
#   'he',
#   'her',
#   'here',
# ...

# %%
def clean_review(words):
    output_words = []
    for w in words:
        if w.lower() not in stops:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
documents = [(clean_review(document), category) for document, category in documents]

# %%
documents[0]
# Out:
# (['footloose',
#   'one',
#   'goal',
#   'mind',
#   'reel',
#   'audience',
#   'cheesy',
#   'sentiment',
#   'feel',
#   'good',
#   'antic',
#   'hate',
#   'admit',
#   'fell',
#   'movie',
#   'teenager',
#   'bacon',
#   'move',
#   'small',
#   'town',
#   'big',
#   'city',
#   'discovers',
#   'dance',
#   'ban',
#   'local',
#   'reverend',
#   'lithgow',
#   'end',
#   'fall',
#   'preacher',
#   'daughter',
#   'singer',
#   'show',
#   'whole',
#   'town',
#   'magic',
#   'dance',
#   'mention',
#   'begin',
#   'review',
#   'footloose',
#   'extremely',
#   'hokey',
#   'predictable',
#   'teen',
#   'drama',
#   'virtually',
#   'surprise',
#   'write',
#   'second',
#   'rate',
#   'enjoy',
#   'much',
#   'one',
#   'thing',
#   'cast',
#   'great',
#   'kevin',
#   'bacon',
#   'ooze',
#   'charisma',
#   'early',
#   'role',
#   'root',
#   'right',
#   'start',
#   'unlike',
#   'film',
#   'genre',
#   'bacon',
#   'play',
#   'rebel',
#   'without',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
train_set = {"the sky sky is blue", "the sun is bright"} #dummy data
count_vec = CountVectorizer(max_features = 3) #it will pick the highest frequency words
a = count_vec.fit_transform(train_set)
a.todense() #to_dense --> used to show the sparse matrix
# Out:
# matrix([[1, 2, 1],
#         [1, 0, 1]], dtype=int64)

# %%
count_vec.get_feature_names() #tells us the feature names we are picking for CV
#add sky in train_set[0]
# Out:
# ['is', 'sky', 'the']

# %%
categories = [category for document, category in documents]

# %%
len(categories)
# Out:
# 2000

# %%
#intuition for code below
a = ["ad", "is"]
" ".join(a)
# Out:
# 'ad is'

# %%
text_documents = [" ".join(document) for document, category in documents]

# %%
text_documents[0]
# Out:
# 'footloose one goal mind reel audience cheesy sentiment feel good antic hate admit fell movie teenager bacon move small town big city discovers dance ban local reverend lithgow end fall preacher daughter singer show whole town magic dance mention begin review footloose extremely hokey predictable teen drama virtually surprise write second rate enjoy much one thing cast great kevin bacon ooze charisma early role root right start unlike film genre bacon play rebel without clue sort yes rebel also polite need never brood rest cast equally impressive john lithgow see play normal guy change play man would normally flat villian lithgow play concerned father try feel best daughter end film feel genuine sense love understand lori singer character another nice touch music see parent kid complain music listen fill sexual innuendo true title track perform kenny loggins upbeat fun final sequence overcome urge get couch start dance course soon realize would little pathetic anyway footloose charm 
# ...

# %%
#Now ew have our categories as well as text_documents

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(text_documents, categories)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ec4721f883b4> in <module>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(text_documents, categories)
#
# NameError: name 'text_documents' is not defined

# %%
#Now creating CV
count_vec = CountVectorizer(max_features = 3)
x_train_features = count_vec.fit_transform(x_train)
x_train_features.todense()
# Out:
# matrix([[2, 9, 2],
#         [4, 2, 0],
#         [0, 0, 0],
#         ...,
#         [2, 1, 2],
#         [3, 6, 1],
#         [8, 5, 3]], dtype=int64)

# %%
count_vec.get_feature_names()
# Out:
# ['film', 'movie', 'one']

# %%
#Now creating CV
count_vec = CountVectorizer(max_features = 2000, ngram_range=(2,3))
x_train_features = count_vec.fit_transform(x_train)
x_train_features.todense()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f20452df4f1b> in <module>()
#       1 #Now creating CV
#       2 count_vec = CountVectorizer(max_features = 2000) #ngram_range=(2,3))
# ----> 3 x_train_features = count_vec.fit_transform(x_train)
#       4 x_train_features.todense()
#
# NameError: name 'x_train' is not defined

# %%
count_vec.get_feature_names()
# Out:
# ['10 10',
#  '10 minute',
#  '10 scale',
#  '10 year',
#  '100 million',
#  '14 year',
#  '15 minute',
#  '17 year',
#  '19th century',
#  '20 minute',
#  '20 year',
#  '20th century',
#  '30 minute',
#  '90 minute',
#  'able get',
#  'able make',
#  'absolutely nothing',
#  'academy award',
#  'ace ventura',
#  'act ability',
#  'act film',
#  'act like',
#  'act skill',
#  'act talent',
#  'action adventure',
#  'action comedy',
#  'action film',
#  'action flick',
#  'action hero',
#  'action movie',
#  'action scene',
#  'action sequence',
#  'action thriller',
#  'actor film',
#  'actor play',
#  'actually get',
#  'actually work',
#  'adam sandler',
#  'adult film',
#  'african american',
#  'albert brook',
#  'alec baldwin',
#  'alien resurrection',
#  'almost always',
#  'almost entirely',
#  'almost every',
#  'along line',
#  'along way',
#  'already know',
#  'already see',
#  'also feature',
#  'also funny',
#  'also get',
#  'also give',
#  'also good',
# ...

# %%
count_vec.get_feature_names()
# Out:
# ['000',
#  '10',
#  '100',
#  '13',
#  '15',
#  '17',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '20',
#  '2000',
#  '30',
#  '50',
#  '60',
#  '70',
#  '80',
#  '90',
#  'abandon',
#  'ability',
#  'able',
#  'absolutely',
#  'academy',
#  'accent',
#  'accept',
#  'accident',
#  'accomplish',
#  'achieve',
#  'across',
#  'act',
#  'action',
#  'actor',
#  'actress',
#  'actual',
#  'actually',
#  'ad',
#  'adam',
#  'adapt',
#  'adaptation',
#  'add',
#  'addition',
#  'admit',
#  'adult',
#  'advance',
#  'adventure',
#  'affair',
#  'affleck',
#  'african',
#  'age',
#  'agent',
#  'ago',
#  'agree',
#  'agrees',
#  'ahead',
#  'aid',
#  'aim',
#  'air',
#  'airplane',
#  'al',
#  'alan',
#  'alex',
#  'alice',
#  'alien',
#  'alive',
#  'allen',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'amaze',
#  'america',
#  'american',
#  'among',
#  'amount',
#  'amuse',
#  'amy',
#  'anderson',
# ...

# %%
x_test_features = count_vec.transform(x_test) #to get our test features

# %%
x_test_features
# Out:
# <500x2000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 85555 stored elements in Compressed Sparse Row format>

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(x_train_features, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svc.score(x_test_features, y_test)
# Out:
# 0.83599999999999997
